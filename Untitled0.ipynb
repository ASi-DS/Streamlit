# %% [markdown]
# <a href="https://colab.research.google.com/github/ASi-DS/Streamlit/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.9 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
st.title("My Streamlit App on Colab")
st.write("Hello from Google Colab!")
# Out:
# Writing app.py

# %%
from pyngrok import ngrok
ngrok.set_auth_token("36Ap8Zb4u9YOTjy8HbhCegSn92P_7DawKSsFoeCW7XhjoXx27")

# %%
# !nohup streamlit run app.py --server.port 8551 &>/dev/null &

# %%
ngrok_tunnel = ngrok.connect(addr="8551", proto="http", bind_tls=True)
print("Streamlit App URL:", ngrok_tunnel.public_url)
# Out:
# Streamlit App URL: https://solitarily-supereffective-dione.ngrok-free.dev
